# %% [markdown]
# # Project: Geo-pulse - Clustering of area_codes

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Importing Libraries

# %%
# General Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Sci-kit learn Library
# machine learning models
from sklearn.cluster import KMeans, DBSCAN
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from sklearn.ensemble import RandomForestClassifier

# preprocess
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# metrics
from sklearn.metrics import mean_squared_error, silhouette_score, \
classification_report, ConfusionMatrixDisplay, confusion_matrix
from kneed import KneeLocator

sns.set_palette('colorblind')

# %%
df = pd.read_csv('../data/geo_cleaned.csv', index_col=[0])

# %%
df.drop(columns=['area_code','hour'],inplace=True)

# %%
df.head()
# Out:
#         segment  density  pre_paid  post_paid  gender_male  gender_female  \
# 0       visitor      431       113        318          131            137
# 1  work_at_home      268       117        151           67             57
# 2  work_at_home      261       103        158           59             66
# 3  work_at_home      255        98        157           61             49
# 4  work_at_home      254       113        141           57             70
#
#    gender_unknown  age_1_19  age_20_29  age_30_39  ...  pct_fastfood_app_user  \
# 0             163       152         64         53  ...               0.023202
# 1             144        21         57         69  ...               0.018657
# 2             136        26         56         59  ...               0.026820
# 3             145        12         63         71  ...               0.019608
# 4             127        25         65         71  ...               0.035433
#
#    pct_food_delivery_app_user  pct_grocery_delivery_app_user  \
# 0                    0.327146                       0.092807
# 1                    0.287313                       0.156716
# 2                    0.287356                       0.137931
# 3                    0.270588                       0.160784
# 4                    0.311024                       0.153543
#
#    pct_inte_coffee_lover  pct_inte_travel_and_information  \
# 0               0.245940                         0.062645
# 1               0.283582                         0.048507
# 2               0.287356                         0.053640
# 3               0.227451                         0.035294
# 4               0.299213                         0.090551
#
#    pct_inte_investment  pct_inte_realestate  pct_inte_insurance  \
# 0             0.078886             0.032483            0.030162
# 1             0.085821             0.055970            0.037313
# 2             0.137931             0.057471            0.076628
# 3             0.090196             0.047059            0.043137
# 4             0.082677             0.051181            0.051181
#
#    pct_inte_automobile  pct_inte_fitness_and_wellness
# 0             0.064965                       0.160093
# 1             0.078358                       0.059701
# 2             0.103448                       0.076628
# 3             0.078431                       0.062745
# 4             0.078740                       0.059055
#
# [5 rows x 65 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# **Drop % columns**

# %%
df.drop(columns = df.columns[df.columns.str.contains('pct')].to_list(),inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. KMeans by time of the day

# %% [markdown]
# We have separated our segments into 4 segments - `visitor`, `worker`, `resident`, and `work_at_home` - because every grid is unique, therefore comparing different segments at different locations will not be beneficial. Focusing on each segment, we will do unsupervised clustering based on `time_of_day` - `Morning`, `Work`, `Afterwork`, `Sleep`. This should be able to provide us with some clues on how the grids can be cluster and what sets each grids apart.
#
# However, if each binning of segments and time_of_day has too little rows of data, then clustering will not work. We will select only grids with > 20 rows to do clustering.

# %%
grouped = df.groupby(['time_of_day'])['density'].count()\
.to_frame()
grouped['Usability'] = grouped['density'].map(
    lambda x : np.where(x < 20, 'too small', 'can use'))

# %%
grouped.style.background_gradient()
# Out:
# <style type="text/css">
# #T_ea874_row0_col0 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_ea874_row1_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ea874_row2_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_ea874_row3_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ea874">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea874_level0_col0" class="col_heading level0 col0" >density</th>
#       <th id="T_ea874_level0_col1" class="col_heading level0 col1" >Usability</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >time_of_day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea874_level0_row0" class="row_heading level0 row0" >Afterwork</th>
#       <td id="T_ea874_row0_col0" class="data row0 col0" >166</td>
#       <td id="T_ea874_row0_col1" class="data row0 col1" >can use</td>
#     </tr>
#     <tr>
#       <th id="T_ea874_level0_row1" class="row_heading level0 row1" >Morning</th>
#       <td id="T_ea874_row1_col0" class="data row1 col0" >100</td>
#       <td id="T_ea874_row1_col1" class="data row1 col1" >can use</td>
#     </tr>
#     <tr>
#       <th id="T_ea874_level0_row2" class="row_heading level0 row2" >Sleep</th>
#       <td id="T_ea874_row2_col0" class="data row2 col0" >149</td>
#       <td id="T_ea874_row2_col1" class="data row2 col1" >can use</td>
#     </tr>
#     <tr>
#       <th id="T_ea874_level0_row3" class="row_heading level0 row3" >Work</th>
#       <td id="T_ea874_row3_col0" class="data row3 col0" >223</td>
#       <td id="T_ea874_row3_col1" class="data row3 col1" >can use</td>
#     </tr>
#   </tbody>
# </table>

# %%
def cluster(segment,time, max_cluster):
    
    X = segment[segment['time_of_day'] == time].drop(
        columns=['segment','time_of_day','density'])
    #X_sc = MinMaxScaler().fit_transform(X)
    
    # Inertia
    km = KMeans(random_state=42)
    visualizer = KElbowVisualizer(km,k=(2,max_cluster))
    visualizer.fit(X)
    visualizer.show()
    
    # Silhouette Score
    fig, ax = plt.subplots(max_cluster//2, 2, figsize=(10,max_cluster))
    
    for i in range(2,max_cluster+1):

        km = KMeans(n_clusters=i, init='k-means++', n_init=10,
                    max_iter=100, random_state=42)
        q, mod = divmod(i, 2)
        
        visualizer = SilhouetteVisualizer(km, colors='yellowbrick',
                                          ax=ax[q-1][mod])
        visualizer.fit(X)
        
    plt.tight_layout()

# %% [markdown]
# ### 3.1 Visitors

# %% [markdown]
# #### 3.1.1 Morning Hours

# %%
cluster(visitor,'Morning',10)

# %% [markdown]
# #### 3.1.2 Working Hours

# %%
cluster(visitor,'Work',10)

# %% [markdown]
# #### 3.1.3 Afterwork

# %%
cluster(visitor,'Afterwork',10)

# %% [markdown]
# #### 3.1.4 Sleeping time

# %%
cluster(visitor,'Sleep',10)

# %% [markdown]
# ### 3.2 Worker

# %% [markdown]
# #### 3.2.1 Morning Hours

# %%
cluster(worker,'Morning',10)

# %% [markdown]
# #### 3.2.2 Working Hours

# %%
cluster(worker,'Work',11)

# %% [markdown]
# ### 3.3 Resident

# %% [markdown]
# #### 3.3.1 Morning Hours

# %%
cluster(resident,'Morning',11)

# %% [markdown]
# #### 3.3.2 Sleeping time

# %%
cluster(resident,'Sleep',10)

# %% [markdown]
# ### 3.4 Work From Home

# %% [markdown]
# #### 3.4.1 Morning Hours

# %%
cluster(work_at_home,'Morning',10)
# Out:
# /Users/smile/Applications/anaconda3/lib/python3.9/site-packages/yellowbrick/utils/kneed.py:156: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# /Users/smile/Applications/anaconda3/lib/python3.9/site-packages/yellowbrick/cluster/elbow.py:374: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)

# %% [markdown]
# #### 3.4.2 Working Hours

# %%
cluster(work_at_home,'Work',10)

# %% [markdown]
# #### 3.4.3 Afterwork

# %%
cluster(work_at_home,'Afterwork',10)

# %% [markdown]
# #### 3.4.4 Sleeping time

# %%
cluster(work_at_home,'Sleep',10)

# %% [markdown]
# ## 4. Unsupervised KMeans clustering feeding into Supervised classifier to identify feature importance

# %% [markdown]
# **Testing on `visitors` segment during `morning` hours using 4 clusters**

# %%
def km_label(segment,time_of_day,num_clusters):
    X = segment[segment['time_of_day'] == time_of_day].drop(
        columns=['segment','time_of_day','density'])
    km = KMeans(n_clusters=num_clusters, random_state=42)
    km.fit(X)
    clf_df = X.copy()
    clf_df['labels'] = km.labels_
    
    return clf_df

# %%
def clf_reports(model,clf_df):
    clf = model
    X = clf_df.drop(columns=['labels'])
    y = clf_df['labels']
    X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    
    print(classification_report(y_test,y_pred))
    
    result = pd.DataFrame({'feature':clf.feature_names_in_,
                                       'importance':clf.feature_importances_})
    result = result.sort_values(by='importance',ascending=False)
    return result

# %%
clf_df = km_label(work_at_home,'Work',4)
important_features = clf_reports(RandomForestClassifier(random_state=42),clf_df)
important_features.head(5)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         8
#            1       0.82      1.00      0.90         9
#            2       1.00      0.40      0.57         5
#            3       1.00      0.67      0.80         3
#
#     accuracy                           0.84        25
#    macro avg       0.90      0.77      0.79        25
# weighted avg       0.87      0.84      0.82        25
#                          feature  importance
# 10                 pct_post_paid    0.109828
# 9                   pct_pre_paid    0.107799
# 2             pct_gender_unknown    0.078369
# 17  pct_video_streaming_app_user    0.073451
# 12                 pct_pay_0to99    0.059097
